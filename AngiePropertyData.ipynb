# %%
import csv
import pandas as pd

# %%
# Create a reference to the CSV and import it into a Pandas DataFrame
csv_path = "../Project1/property_csv.csv"
property_df = pd.read_csv(csv_path)

# %%
property_df.head(20)
# Out:
#     Zip Code Property Type Avg. Sq Ft  Avg. Market Value  Avg. Year Built  \
# 0      78745         Condo       1,648         $250,306              2007
# 1      78745       Duplex        2,376         $334,159              1984
# 2      78745         House       2,024         $316,202              1982
# 3      78705         Condo         887         $291,485              1983
# 4      78705       Duplex        2,665         $592,842              1945
# 5      78705         House       2,248         $664,104              1938
# 6      78729         Condo       1,726         $263,887              2008
# 7      78729       Duplex        2,161         $336,818              1985
# 8      78729         House       2,037         $312,731              1987
# 9      78732         Condo       3,178         $475,480              2012
# 10     78732       Duplex        4,885         $639,797              1978
# 11     78732         House       3,855         $596,332              2001
# ...
