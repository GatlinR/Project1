# %%
import requests
import json
from pprint import pprint
import pandas as pd

# %%
#Search for all property types in zip code 78745 (Travis County-near Lake Travis)
payload = {
    'Accept': 'application/json',
    'apikey': '5a02104b4076981f3a2fbab6c6908160',
    'accept': 'application/json'
}
url = "https://api.gateway.attomdata.com/propertyapi/v1.0.0/assessment/detail?postalcode=78745&pagesize=1"
s = requests.Session()
response = s.get(url, headers = payload)
json_response = response.json()
#pprint(json_response)
market_value = []
sq_ft = []
zip_code = []
prop_type = []
year_built = []
for item in json_response['property']:
    market_value.append(item['assessment']['market']['mktttlvalue'])
    sq_ft.append(item['building']['size']['bldgsize'])
    zip_code.append(item['address']['postal1'])
    prop_type.append(item['summary']['proptype'])
    year_built.append(item['summary']['yearbuilt'])
df_78745 = pd.DataFrame({"Zip Code": zip_code, "Property Type": prop_type, "Square Feet": sq_ft, "Market Value": market_value,
                  "Year Built": year_built})
#Add Price per SqFt column 
df_78745["Price per SqFt"] = round(df_78745["Market Value"]/df_78745["Square Feet"],2)
#Get rid of rows with zero in data
df_78745 = df_78745.loc[df_78745["Square Feet"]!=0,:]
#Narrow down dataframe to propery types we want to look at
df_78745 = df_78745.loc[(df_78745["Property Type"]=="CONDOMINIUM")|(df_78745["Property Type"]=="DUPLEX")|
                        (df_78745["Property Type"]=="SFR")|(df_78745["Property Type"]=="MULTI FAMILY DWELLING"),:]
df_78745

#Calculate average price per sqft for Condominium, Duplex, SFR, and Family Dwelling

#Find average house value (SFR), plot Year Built vs. Market Value of SFR on line graph to see how it changes over time
#Does age of house affect its market value?

#Hadis
#Find count of each property type, what property types are most popular? 


#Find count of Condominium, Duplex, SFR, and Family Dwelling based on year built
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-3-e67ee6f1e685> in <module>
#       8 s = requests.Session()
#       9 response = s.get(url, headers = payload)
# ---> 10 json_response = response.json()
#      11 #pprint(json_response)
#      12 market_value = []
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     887                 try:
#     888                     return complexjson.loads(
# --> 889                         self.content.decode(encoding), **kwargs
#     890                     )
#     891                 except UnicodeDecodeError:
#
# ~\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Unterminated string starting at: line 1 column 73339 (char 73338)

# %% [markdown]
# 78705 is a densely populated, upscale urban zip code in Austin, Texas. Median household income here ($14,740) is significantly lower than US average ($56,604). The population is primarily white, younger, and mostly single.

# %%
#Search for all property types in zip code 78705 (West Campus-Travis County)
payload = {
    'Accept': 'application/json',
    'apikey': '5a02104b4076981f3a2fbab6c6908160',
    'accept': 'application/json'
}
url = "https://api.gateway.attomdata.com/propertyapi/v1.0.0/assessment/detail?postalcode=78705&pagesize=30"
s = requests.Session()
response = s.get(url, headers = payload)

json_response = response.json()
#pprint(json_response)
market_value = []
sq_ft = []
zip_code = []
prop_class = []
year_built = []
for item in json_response['property']:
    try: 
        market_value.append(item['assessment']['market']['mktttlvalue'])
        sq_ft.append(item['building']['size']['bldgsize'])
        zip_code.append(item['address']['postal1'])
        prop_class.append(item['summary']['proptype'])
        year_built.append(item['summary']['yearbuilt'])
    except ValueError:
        print("Not found")
df_78705 = pd.DataFrame({"Zip Code": zip_code, "Property Type": prop_class, "Square Feet": sq_ft, 
                         "Market Value": market_value, "Year Built": year_built})
#Add Price per SqFt column 
df_78705["Price per SqFt"] = round(df_78705["Market Value"]/df_78705["Square Feet"],2)
#Get rid of rows with zero in data
df_78705 = df_78705.loc[df_78705["Square Feet"]!=0,:]
df_78705 = df_78705.loc[(df_78705["Property Type"]=="CONDOMINIUM")|(df_78705["Property Type"]=="DUPLEX")|
                        (df_78705["Property Type"]=="SFR")|(df_78705["Property Type"]=="MULTI FAMILY DWELLING"),:]
df_78705
# Out:
#    Zip Code          Property Type  Square Feet  Market Value  Year Built  \
# 17    78705  MULTI FAMILY DWELLING         2816        675840        1916
# 20    78705            CONDOMINIUM         3997        895100        1934
# 26    78705            CONDOMINIUM          652        240785        1982
# 27    78705            CONDOMINIUM          884        311665        1982
# 28    78705            CONDOMINIUM          879        291716        1982
# 29    78705            CONDOMINIUM          893        314845        1982
#
#     Price per SqFt
# 17          240.00
# 20          223.94
# 26          369.30
# 27          352.56
# 28          331.87
# 29          352.57

# %% [markdown]
# The people living in ZIP code 78729 are primarily white. The number of people in their late 20s to early 40s is extremely large while the number of seniors is small. There are also an extremely large number of single adults and a small number of families. The percentage of children under 18 living in the 78729 ZIP code is slightly less than average compared to other areas of the country.

# %%
#Search for all property types in zip code 78729 (Suburb-Willamson County)
payload = {
    'Accept': 'application/json',
    'apikey': '5a02104b4076981f3a2fbab6c6908160',
    'accept': 'application/json'
}
url = "https://api.gateway.attomdata.com/propertyapi/v1.0.0/assessment/detail?postalcode=78729&pagesize=30"
s = requests.Session()
response = s.get(url, headers = payload)

json_response = response.json()
#pprint(json_response)
market_value = []
sq_ft = []
zip_code = []
prop_class = []
year_built = []
for item in json_response['property']:
    try: 
        market_value.append(item['assessment']['market']['mktttlvalue'])
        sq_ft.append(item['building']['size']['bldgsize'])
        zip_code.append(item['address']['postal1'])
        prop_class.append(item['summary']['proptype'])
        year_built.append(item['summary']['yearbuilt'])
    except ValueError:
        print("Not found")
df_78729 = pd.DataFrame({"Zip Code": zip_code, "Property Type": prop_class, "Square Feet": sq_ft, 
                         "Market Value": market_value,"Year Built":year_built})
#Add price per sqft column
df_78729["Price per SqFt"] = round(df_78729["Market Value"]/df_78729["Square Feet"],2)
#Get rid of rows with zero in data
df_78729 = df_78729.loc[df_78729["Square Feet"]!=0,:]
df_78729 = df_78729.loc[(df_78729["Property Type"]=="CONDOMINIUM")|(df_78729["Property Type"]=="DUPLEX")|
                        (df_78729["Property Type"]=="SFR")|(df_78729["Property Type"]=="MULTI FAMILY DWELLING"),:]
df_78729
# Out:
#    Zip Code Property Type  Square Feet  Market Value  Year Built  \
# 2     78729   CONDOMINIUM         1663        239525        2003
# 3     78729   CONDOMINIUM         1663        239525        2003
# 10    78729   CONDOMINIUM         1592        244799        2003
# 20    78729   CONDOMINIUM         1663        239525        2003
# 22    78729   CONDOMINIUM         1501        230599        2002
# 23    78729   CONDOMINIUM         1663        239525        2003
# 24    78729   CONDOMINIUM         1592        244799        2003
# 25    78729   CONDOMINIUM         1592        235653        2003
# 26    78729   CONDOMINIUM         1818        258681        2003
# 27    78729   CONDOMINIUM         1818        249020        2003
# 28    78729   CONDOMINIUM         1663        239525        2003
# 29    78729   CONDOMINIUM         1454        229721        2003
#
#     Price per SqFt
# 2           144.03
# 3           144.03
# 10          153.77
# 20          144.03
# 22          153.63
# 23          144.03
# 24          153.77
# 25          148.02
# 26          142.29
# 27          136.97
# 28          144.03
# 29          157.99

# %%
#
#Find count of each property type, what property types are most popular?

#gruup dataframe by property type
df_78745_group = df_78745.groupby(df_78745["Property Type"])

#count of each property type
df_78745_gtoup_count = df_78745_group.count()["Zip Code"]

#convert the data to dataframe
df_78745_gtoup_count.to_frame(name = "Count of each property")

#Find count of each property type, what property types are most popular?

#gruup dataframe by property type
df_78705_group = df_78705.groupby(df_78705["Property Type"])

#count of each property type
df_78705_gtoup_count = df_78705_group.count()["Square Feet"]

#convert the data to dataframe
df_78705_gtoup_count.to_frame(name = "Count of each property")


#Find count of each property type, what property types are most popular?

#gruup dataframe by property type
df_78729_group = df_78729.groupby(df_78729["Property Type"])

#count of each property type
df_78729_gtoup_count = df_78729_group.count()["Year Built"]

#convert the data to dataframe
df_78729_gtoup_count.to_frame(name = "Count of each property")



#merge seveal data frame to make it one:
df_combined=[df_78745_gtoup_count,df_78705_gtoup_count, df_78729_gtoup_count]
#count_df= pd.merge(df_78745_gtoup_count, df_78705_gtoup_count, how= "outer" , on="Property Type" )

result = pd.concat(df_combined, join='outer', axis=1)

rename_result = result.rename(columns={"Zip Code": "78745", "Square Feet": "78705","Year Built": "78729" })

rename_result


#create a Grouped bar chart with labels
labels = ["CONDOMINIUM", "DUPLEX", "MULTI FAMILY DWELLING", "SFR"]
property_count_78745 = rename_result["78745"]
property_count_78705 = rename_result["78705"]
property_count_78729 = rename_result["78729"]

#plt.bar(rename_result, height = )

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, property_count_78745, width, label='property count for 78745')
rects2 = ax.bar(x , property_count_78705, width, label='property count for 78705')
rects3 = ax.bar(x + width, property_count_78729, width, label='property count for 78729')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Count')
ax.set_title('Property count for each zipcode')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


autolabel(rects1)
autolabel(rects2)
autolabel(rects3)

plt.ylim(0,9000)

fig.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-acf090fbedd0> in <module>
#      19
#      20
# ---> 21 autolabel(rects1)
#      22 autolabel(rects2)
#      23 autolabel(rects3)
#
# NameError: name 'autolabel' is not defined

# %%
#Build a heat map that overlays the zip codes over Austin
#Use lat and long of each zip code as locations and price/sqft as the weight
#Plot markers that show price/sqft over each property 
#Does geography/location/land features affect the market value of homes?
